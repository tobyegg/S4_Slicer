# %%
import zipfile
import os
from pathlib import Path
import shutil
# testing how to zip 3mf correctly - using dino in input models
# zipList = [f'./input_models/dino/{x}' for x in os.listdir("./input_models/dino")]
# # ziplist contains (filepath, archive_path)
# zipList = [(f'./input_models/dino/{x}/', x) if os.path.isdir(f"./input_models/dino/{x}") else (f'./input_models/dino/{x}', f'{x}/') for x in os.listdir("./input_models/dino")]
# print(zipList)
# myZip = zipfile.ZipFile("./input_models/dino_test.zip", mode='w') # write mode
# for filepath, arcpath in zipList:
#     myZip.write(filename=filepath, arcname=arcpath)
# myZip.close()

# with shutil.make_archive
shutil.make_archive(base_name=f"./input_models/dino_test", format="zip", root_dir="./input_models/dino", base_dir='.')

# rename as dino_test.3mf and delete .zip
print(f"Casting zip archives to 3MF")
in_mf_path = Path(f'./input_models/dino_test.zip')
in_mf_path.rename(in_mf_path.with_suffix('.3mf'))
# Out:
# '/home/bearable/nonplanar-infill/S4_Slicer/input_models/dino_test.zip'
